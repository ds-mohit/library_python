# %% [markdown]
# # What is ```Matplotlib?```
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# Matplotlib was created by John D. Hunter.
#
# Matplotlib is open source and we can use it freely.
#
# Matplotlib is mostly written in python, a few segments are written in C, Objective-C and Javascript for Platform compatibility.

# %% [markdown]
# # What is ```Seaborn?```
# Seaborn is a powerful Python data visualization library built on top of matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
arr=np.random.randint(20000,40000,100)
arr
# Out:
# array([38750, 32639, 30127, 37649, 26828, 34511, 37300, 31147, 22805,
#        32139, 21370, 32763, 27318, 38086, 29436, 21441, 38446, 28032,
#        38718, 27765, 34175, 23406, 29393, 25703, 25600, 22049, 20422,
#        21442, 36201, 26779, 27265, 31331, 24545, 24458, 38255, 38069,
#        27905, 27736, 27983, 32725, 36596, 26127, 32959, 30013, 26658,
#        24184, 27431, 26175, 36802, 34525, 24489, 37125, 20120, 27575,
#        36580, 37401, 35861, 27517, 31253, 36271, 27440, 39068, 25792,
#        27022, 26430, 23767, 35330, 36354, 31984, 35440, 38535, 31174,
#        38984, 36154, 21732, 33035, 30770, 38097, 23198, 33402, 39672,
#        38028, 27023, 30041, 38079, 29335, 38048, 22398, 20498, 30995,
#        27026, 23669, 31414, 28745, 23782, 34059, 37188, 27425, 39079,
#        30813], dtype=int32)

# %%
plt.plot(arr)
plt.savefig('plot.png')
plt.show()

# %%
arr.sort()
plt.plot(arr)
plt.savefig('plot_arr.png')
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,10,9,30,25]
plt.plot(x,y,marker='o')
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,10,9,30,25]
plt.plot(x,y,marker='o',ms=15)
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,10,9,30,25]
plt.plot(x,y,marker='o',ms=15,mfc='r')
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,10,9,30,25]
plt.plot(x,y,marker='o',ms=15,mfc='r',mec='b')
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,10,9,30,25]
plt.plot(x,y,marker='o',ms=15,mfc='r',mec='b',color="black")
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,10,9,30,25]
plt.plot(x,y,marker='o',ms=15,mfc='r',mec='b',color='black',ls="--")
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,10,9,30,25]
plt.plot(x,y,marker='o',
         ms=15,
         mfc='r',
         mec='b',
         color='black',
         ls="--",
         alpha=0.7)
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,10,9,30,25]
plt.plot(x,y,marker='o',
         ms=15,
         mfc='r',#marker face color
         mec='b',#marker edge color
         color='black',
         ls="--",#line space 
         alpha=0.7,#blurness
         label='lineplot')
plt.savefig('plot_attributes.png')
plt.show()

# %%
x=[1,2,3,4,5]
y=[1,10,9,30,25]
plt.plot(x,y,marker='o',
         ms=15,
         mfc='r',#marker face color
         mec='b',#marker edge color
         color='black',
         ls="--",#line space 
         alpha=0.7,#blurness
         label='lineplot',)
plt.title('Matplotlib_Graph')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.savefig('plot_methods.png')
plt.show()

# %% [markdown]
# # ```scatter plot```
# #another type of plot

# %%
plt.scatter(x,y)
plt.savefig('scatter.png')
plt.show()

# %%
plt.scatter(x,y,marker='o',s=120,c='red',edgecolors='green',alpha=0.5)
plt.savefig('scatter_attributes.png')
plt.show()

# %% [markdown]
# # Bar Graph
# and it is used for categorical data

# %%
x=['ab','bc','cd','de']
y=[10,20,30,40]
colours=['red','green','blue','yellow']
hatch_pattern=['//','xx','++','oo']
plt.bar(x,y,color=colours,hatch= hatch_pattern ,label=x)
plt.legend()
plt.savefig('Bar.png')
plt.show()

# %%
x=['ab','bc','cd','de']
y=[10,20,30,40]
colours=['red','green','blue','yellow']
hatch_pattern=['//','xx','++','oo']
plt.bar(x,y,color=colours,hatch= hatch_pattern ,label=x,width=0.5,edgecolor='black',)
plt.legend()
plt.grid()
plt.savefig('Bar_attributes.png')
plt.show()

# %%
x=['ab','bc','cd','de']
y=[10,20,30,40]
colours=['red','green','blue','yellow']
hatch_pattern=['//','xx','++','oo']
plt.barh(x,y,color=colours,hatch= hatch_pattern ,label=x,edgecolor='black')
plt.legend()
plt.grid()
plt.savefig('Bar_grid.png')
plt.show()

# %% [markdown]
# # histogram

# %%
# histogram
arr=np.random.randint(20000,40000,100)
plt.hist(arr,bins=20)
plt.savefig('Histogram.png')
plt.show()

# %% [markdown]
# # piechart

# %%
x=['ab','bc','cd','de']
y=[5,10,9,30]
plt.pie(y,labels =x)
plt.savefig('Piechart.png')
plt.show()

# %%
x=['ab','bc','cd','de']
y=[5,10,9,30]
plt.pie(y,labels =x,autopct='%1.1f%%')
plt.show()

# %%
x=['ab','bc','cd','de']
y=[1,10,9,30]
explodes=(0.1,0.1,0.1,0.1)  # explode each slice
plt.pie(y,labels =x,autopct='%1.1f%%',explode=explodes)
plt.savefig('Pie_explode.png')
plt.show()

# %%
x=['ab','bc','cd','de']
y=[5,10,9,30]
explodes=(0.1,0.1,0.1,0.1)  # explode each slice
plt.pie(y,labels =x,autopct='%1.1f%%',explode=explodes)
plt.show()

# %%
x=['ab','bc','cd','de']
y=[5,10,9,30]
explodes=(0.1,0.1,0.1,0.1)  # explode each slice
plt.pie(y,labels =x,autopct='%1.1f%%',explode=explodes)
plt.legend()
plt.savefig('pie_legend.png')
plt.show()

# %%
x=['ab','bc','cd','de']
y=[5,10,9,30]
explodes=(0.1,0.1,0.1,0.1)  # explode each slice
plt.pie(y,labels =x,autopct='%1.1f%%',explode=explodes,shadow=True)
plt.savefig('pie_shadow.png')
plt.show()

# %%
x=['ab','bc','cd','de']
y=[5,10,9,30]
explodes=(0.1,0.1,0.1,0.1)  # explode each slice
plt.pie(y,labels =x,autopct='%1.1f%%',explode=explodes,shadow=True,startangle=90)
plt.savefig('pie_startangle.png')
plt.show()

# %%
x=['ab','bc','cd','de']
y=[5,10,9,30]
explodes=(0.1,0.1,0.1,0.1)  # explode each slice
plt.pie(y,labels =x,autopct='%1.1f%%',explode=explodes,shadow=True,startangle=90)
plt.Figure(figsize=(10, 6))
plt.show()

# %% [markdown]
# # subplot

# %%
x=np.linspace(0,10,100)
plt.Figure(figsize=(10, 6))
plt.subplot(2,2,1)# it will create multiple plots of size 2
plt.plot(x,np.sin(x))
plt.title("Sin Wave")
plt.subplot(2,2,2)
plt.plot(x,np.cos(x))
plt.title("Cos-Wave")
plt.subplot(2,2,3)
plt.plot(x,np.tan(x))
plt.title("Tan-Wave")
plt.subplot(2,2,4)
plt.plot(x,np.log(x))
plt.title("Log-Wave")
plt.tight_layout()# this prevent from overlapping
plt.savefig('Subplot.png')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_12716\1931057597.py:13: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x,np.log(x))
